# %%
# !python -V
# Out:
# Python 3.9.16

# %% [markdown]
# # Data Preparation

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import mlflow
import pickle
import os
import numpy as np

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.preprocessing import LabelEncoder
from category_encoders import TargetEncoder

from sklearn.metrics import mean_squared_error

# %%
# Connecting to the AWS S3
os.environ["AWS_PROFILE"] = "default" # fill in with your AWS profile. More info: https://docs.aws.amazon.com/sdk-for-java/latest/developer-guide/setup.html#setup-credentials

TRACKING_SERVER_HOST = "ec2-13-251-63-107.ap-southeast-1.compute.amazonaws.com" # fill in with the public DNS of the EC2 instance
mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")

# Set the new experiment
print(f"tracking URI: '{mlflow.get_tracking_uri()}'")

# Check the experiment
mlflow.search_experiments()
# Out:
# tracking URI: 'http://ec2-13-251-63-107.ap-southeast-1.compute.amazonaws.com:5000'
# [<Experiment: artifact_location='s3://mlflow-artifacts-remote-zoomcamp/2', creation_time=1688375544076, experiment_id='2', last_update_time=1688375544076, lifecycle_stage='active', name='my-experiment-1', tags={}>,
#  <Experiment: artifact_location='s3://mlflow-artifacts-remote-zoomcamp/1', creation_time=1688358175294, experiment_id='1', last_update_time=1688358175294, lifecycle_stage='active', name='my-experiment-2', tags={}>,
#  <Experiment: artifact_location='s3://mlflow-artifacts-remote-zoomcamp/0', creation_time=1688358000094, experiment_id='0', last_update_time=1688358000094, lifecycle_stage='active', name='Default', tags={}>]

# %%
# kaggle datasets download -d mchirico/montcoalert

dataset_name = "spotify-and-youtube"
# !kaggle datasets download -d salvatorerastelli/{dataset_name}
# !mkdir data
# !cd data
# !mkdir {dataset_name}
# !unzip -o {dataset_name}.zip -d /home/ubuntu/mlops_project/data/{dataset_name}/
# Out:
# Downloading spotify-and-youtube.zip to /home/ubuntu/mlops_project/MLOPS-Project-911_Emergency_Call/experiment_tracking
# 100%|██████████████████████████████████████| 8.95M/8.95M [00:01<00:00, 9.45MB/s]
# 100%|██████████████████████████████████████| 8.95M/8.95M [00:01<00:00, 5.65MB/s]
# Archive:  spotify-and-youtube.zip
#   inflating: /home/ubuntu/mlops_project/data/spotify-and-youtube/Spotify_Youtube.csv

# %%
# Read the CSV file and check
df = pd.read_csv("/home/ubuntu/mlops_project/data/spotify-and-youtube/Spotify_Youtube.csv")

# %%
# Reset the index to be starting from 1 not zero
df = df.reset_index(drop=True)
df.index = df.index + 1

# show the table
df.head(2)
# Out:
#    Unnamed: 0    Artist                                        Url_spotify
# 1           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...  \
# 2           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#              Track          Album Album_type
# 1   Feel Good Inc.     Demon Days      album  \
# 2  Rhinestone Eyes  Plastic Beach      album
#
#                                     Uri  Danceability  Energy  Key  ...
# 1  spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705  6.0  ...  \
# 2  spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703  8.0  ...
#
#                                    Url_youtube
# 1  https://www.youtube.com/watch?v=HyHNuVaZJ-k  \
# 2  https://www.youtube.com/watch?v=yYDmaexVHic
#
#                                                Title   Channel        Views
# 1         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0  \
# 2  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description
# 1  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...  \
# 2  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed official_video        Stream
# 1      True           True  1.040235e+09
# 2      True           True  3.100837e+08
#
# [2 rows x 28 columns]

# %%
# Rename all the column to be nice to see
df['Trending'] = df.shape[0] + 1 - df['Views'].rank()
df = df.sort_values(by='Trending', ascending=True)

df = df[(df.Trending >= 1)]

# Drop some unnecessary file
df = df.dropna()
df = df.drop('Url_spotify', axis=1)
df = df.drop('Uri', axis=1)

df.head()
# Out:
#        Unnamed: 0        Artist                               Track
# 1148         1147    Luis Fonsi                           Despacito  \
# 366           365  Daddy Yankee                           Despacito
# 12453       12452    Ed Sheeran                        Shape of You
# 14581       14580  Charlie Puth  See You Again (feat. Charlie Puth)
# 12470       12469   Wiz Khalifa  See You Again (feat. Charlie Puth)
#
#                                     Album Album_type  Danceability  Energy
# 1148                                 VIDA      album         0.655   0.797  \
# 366                                  VIDA      album         0.655   0.797
# 12453                          ÷ (Deluxe)      album         0.825   0.652
# 14581  See You Again (feat. Charlie Puth)     single         0.689   0.481
# 12470  See You Again (feat. Charlie Puth)     single         0.689   0.481
#
#         Key  Loudness  Speechiness  ...
# 1148    2.0    -4.787       0.1530  ...  \
# 366     2.0    -4.787       0.1530  ...
# 12453   1.0    -3.183       0.0802  ...
# 14581  10.0    -7.503       0.0815  ...
# 12470  10.0    -7.503       0.0815  ...
#
#                                                    Title            Channel
# 1148             Luis Fonsi - Despacito ft. Daddy Yankee      LuisFonsiVEVO  \
# 366              Luis Fonsi - Despacito ft. Daddy Yankee      LuisFonsiVEVO
# 12453   Ed Sheeran - Shape of You (Official Music Video)         Ed Sheeran
# 14581  Wiz Khalifa - See You Again ft. Charlie Puth [...  Wiz Khalifa Music
# 12470  Wiz Khalifa - See You Again ft. Charlie Puth [...  Wiz Khalifa Music
#
#               Views       Likes   Comments
# 1148   8.079649e+09  50788652.0  4252791.0  \
# 366    8.079647e+09  50788626.0  4252791.0
# 12453  5.908398e+09  31047780.0  1130327.0
# 14581  5.773798e+09  40147674.0  2127346.0
# 12470  5.773797e+09  40147618.0  2127345.0
#
#                                              Description Licensed
# 1148   “Despacito” disponible ya en todas las platafo...     True  \
# 366    “Despacito” disponible ya en todas las platafo...     True
# 12453  The official music video for Ed Sheeran - Shap...     True
# 14581  Download the new Furious 7 Soundtrack Deluxe V...     True
# 12470  Download the new Furious 7 Soundtrack Deluxe V...     True
#
#       official_video        Stream  Trending
# 1148            True  1.506598e+09     471.0
# 366             True  1.506598e+09     472.0
# 12453           True  3.362005e+09     473.0
# 14581           True  1.521255e+09     474.0
# 12470           True  1.521255e+09     475.0
#
# [5 rows x 27 columns]

# %%
# Select only numerical columns
numerical_columns = df.select_dtypes(include=[np.number]).columns

# Calculate correlation
correlation = df[numerical_columns].corr()['Trending']
print(correlation)
# Out:
# Unnamed: 0         -0.042535
# Danceability       -0.153034
# Energy             -0.178070
# Key                -0.019986
# Loudness           -0.285794
# Speechiness         0.029659
# Acousticness        0.162451
# Instrumentalness    0.226587
# Liveness            0.004129
# Valence            -0.091374
# Tempo              -0.045393
# Duration_ms        -0.065395
# Views              -0.479455
# Likes              -0.488178
# Comments           -0.195022
# Stream             -0.465537
# Trending            1.000000
# Name: Trending, dtype: float64

# %%
# Split the file into training data and testing data
split_number = int(len(df)/2)

df_train = df[:split_number]
df_val = df[split_number:]

df.head()
# Out:
#        Unnamed: 0        Artist                               Track
# 1148         1147    Luis Fonsi                           Despacito  \
# 366           365  Daddy Yankee                           Despacito
# 12453       12452    Ed Sheeran                        Shape of You
# 14581       14580  Charlie Puth  See You Again (feat. Charlie Puth)
# 12470       12469   Wiz Khalifa  See You Again (feat. Charlie Puth)
#
#                                     Album Album_type  Danceability  Energy
# 1148                                 VIDA      album         0.655   0.797  \
# 366                                  VIDA      album         0.655   0.797
# 12453                          ÷ (Deluxe)      album         0.825   0.652
# 14581  See You Again (feat. Charlie Puth)     single         0.689   0.481
# 12470  See You Again (feat. Charlie Puth)     single         0.689   0.481
#
#         Key  Loudness  Speechiness  ...
# 1148    2.0    -4.787       0.1530  ...  \
# 366     2.0    -4.787       0.1530  ...
# 12453   1.0    -3.183       0.0802  ...
# 14581  10.0    -7.503       0.0815  ...
# 12470  10.0    -7.503       0.0815  ...
#
#                                                    Title            Channel
# 1148             Luis Fonsi - Despacito ft. Daddy Yankee      LuisFonsiVEVO  \
# 366              Luis Fonsi - Despacito ft. Daddy Yankee      LuisFonsiVEVO
# 12453   Ed Sheeran - Shape of You (Official Music Video)         Ed Sheeran
# 14581  Wiz Khalifa - See You Again ft. Charlie Puth [...  Wiz Khalifa Music
# 12470  Wiz Khalifa - See You Again ft. Charlie Puth [...  Wiz Khalifa Music
#
#               Views       Likes   Comments
# 1148   8.079649e+09  50788652.0  4252791.0  \
# 366    8.079647e+09  50788626.0  4252791.0
# 12453  5.908398e+09  31047780.0  1130327.0
# 14581  5.773798e+09  40147674.0  2127346.0
# 12470  5.773797e+09  40147618.0  2127345.0
#
#                                              Description Licensed
# 1148   “Despacito” disponible ya en todas las platafo...     True  \
# 366    “Despacito” disponible ya en todas las platafo...     True
# 12453  The official music video for Ed Sheeran - Shap...     True
# 14581  Download the new Furious 7 Soundtrack Deluxe V...     True
# 12470  Download the new Furious 7 Soundtrack Deluxe V...     True
#
#       official_video        Stream  Trending
# 1148            True  1.506598e+09     471.0
# 366             True  1.506598e+09     472.0
# 12453           True  3.362005e+09     473.0
# 14581           True  1.521255e+09     474.0
# 12470           True  1.521255e+09     475.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Training Data

# %%
# Set up for features engineering

categorical = ['Licensed']
numerical = ['Views', 'Likes']

dv = DictVectorizer()

train_dicts = df_train[categorical + numerical].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[categorical + numerical].to_dict(orient='records')
X_val = dv.transform(val_dicts)

target = 'Trending'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
# Test the data using simple method

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

mean_squared_error(y_val, y_pred, squared=False)
# Out:
# 9609.787951762835

# %%
# Check the range to assess the quality of our result (using percentage)
range = df['Trending'].max() - df['Trending'].min()
print(range)
# Out:
# 20238.0

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score

# Set the experiment. If the experiment does not exist, it will be created.
mlflow.set_experiment("my-experiment-2")

with mlflow.start_run():
    
    mlflow.set_tag("owner", 'M Irfan')
    
    mlflow.log_param("train-data-path", "/home/ubuntu/mlops_project/data/{dataset_name}.csv")
    
    lr = LinearRegression()
    lr.fit(X_train, y_train)
    
    y_pred = lr.predict(X_val)
    rmse = mean_squared_error(y_val, y_pred, squared = False)
    mlflow.log_metric("rmse", rmse)
    
    mlflow.sklearn.log_model(lr, artifact_path="models")
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
    
    with open('lin_reg.bin', 'wb') as f_out:
        pickle.dump((dv, lr), f_out)
# Out:
# default artifacts URI: 's3://mlflow-artifacts-remote-zoomcamp/1/d7c435b507c643999538790f90fd65c9/artifacts'

# %%
import xgboost as xgb
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

from datetime import datetime
import mlflow.xgboost
import pickle
import boto3
import s3fs

# %%
# Train the data

train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    fs = s3fs.S3FileSystem(anon=False)  # Add this line

    os.environ["AWS_PROFILE"] = "default"
    TRACKING_SERVER_HOST = "ec2-13-251-63-107.ap-southeast-1.compute.amazonaws.com"
    mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")
    
    current_datetime = datetime.now().strftime('%Y-%m-%d_%H:%M:%S.%f')

    with mlflow.start_run():
        print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
        
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
        
        error_percentage = rmse / range * 100
        mlflow.log_metric("error_percentage", error_percentage)

        mlflow.xgboost.save_model(booster, f"/tmp/models_mlflow-{current_datetime}")

        with open(f"/tmp/preprocessor-{current_datetime}.pkl", "wb") as f_out:
            pickle.dump(dv, f_out)

        fs.put(f"/tmp/preprocessor-{current_datetime}.pkl", f"s3://mlflow-artifacts-remote-zoomcamp/mlruns/preprocessor-{current_datetime}.pkl")
        fs.put(f"/tmp/models_mlflow-{current_datetime}", f"s3://mlflow-artifacts-remote-zoomcamp/mlruns/model-{current_datetime}.xgb")

        mlflow.log_artifact(f"/tmp/preprocessor-{current_datetime}.pkl", artifact_path="preprocessor")
        mlflow.log_artifact(f"/tmp/models_mlflow-{current_datetime}", artifact_path="models_mlflow")

        print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")

    return {'loss': rmse, 'status': STATUS_OK}

# %%
def objective1(params):
    fs = s3fs.S3FileSystem(anon=False)  # Add this line

    os.environ["AWS_PROFILE"] = "default"
    TRACKING_SERVER_HOST = "ec2-13-251-63-107.ap-southeast-1.compute.amazonaws.com"
    mlflow.set_tracking_uri(f"http://{TRACKING_SERVER_HOST}:5000")
    
    current_datetime = datetime.now().strftime('%Y-%m-%d_%H:%M:%S.%f')

    with mlflow.start_run():
        print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
        
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)
        
        error_percentage = rmse / range * 100
        mlflow.log_metric("error_percentage", error_percentage)

        mlflow.xgboost.save_model(booster, f"/tmp/models_mlflow-{current_datetime}")

        with open(f"lin_reg.bin", "wb") as f_out:
            pickle.dump(dv, f_out)

        fs.put(f"lin_reg.bin", f"s3://mlflow-artifacts-remote-zoomcamp/mlruns/preprocessor-{current_datetime}.pkl")
        fs.put(f"/tmp/models_mlflow-{current_datetime}", f"s3://mlflow-artifacts-remote-zoomcamp/mlruns/model-{current_datetime}.xgb")

        mlflow.log_artifact(f"lin_reg.bin", artifact_path="lin_reg")
        mlflow.log_artifact(f"/tmp/models_mlflow-{current_datetime}", artifact_path="models_mlflow")

        print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 200, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -6, -3),
    'objective': 'reg:squarederror',
    'seed': 42,
    'verbosity': 3
}

best_result = fmin(
    fn=objective1,
    space=search_space,
    algo=tpe.suggest,
    max_evals=3,
    trials=Trials()
)
# Out:
# default artifacts URI: 's3://mlflow-artifacts-remote-zoomcamp/1/75fb4c2cb1384a0aabc73fbcbeb0f9f1/artifacts'
# [03:49:12] DEBUG: ../src/gbm/gbtree.cc:157: Using tree method: 2
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 78 extra nodes, 0 pruned nodes, max_depth=7
# [0]	validation-rmse:10561.84061
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=8
# [1]	validation-rmse:8112.36988
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 74 extra nodes, 0 pruned nodes, max_depth=7
# [2]	validation-rmse:6952.02805
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 182 extra nodes, 0 pruned nodes, max_depth=8
# [3]	validation-rmse:6391.81709
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 338 extra nodes, 0 pruned nodes, max_depth=12
# [4]	validation-rmse:6122.30117
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 622 extra nodes, 0 pruned nodes, max_depth=16
# [5]	validation-rmse:5987.72722
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 896 extra nodes, 0 pruned nodes, max_depth=19
# [6]	validation-rmse:5921.97607
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1604 extra nodes, 0 pruned nodes, max_depth=23
# [7]	validation-rmse:5891.07659
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2634 extra nodes, 0 pruned nodes, max_depth=32
# [8]	validation-rmse:5873.60855
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3926 extra nodes, 0 pruned nodes, max_depth=36
# [9]	validation-rmse:5864.54940
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5246 extra nodes, 0 pruned nodes, max_depth=44
# [10]	validation-rmse:5860.32831
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6140 extra nodes, 0 pruned nodes, max_depth=43
# [11]	validation-rmse:5857.45549
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6594 extra nodes, 0 pruned nodes, max_depth=52
# [12]	validation-rmse:5855.83579
# [03:49:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6740 extra nodes, 0 pruned nodes, max_depth=50
# [13]	validation-rmse:5854.84717
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6026 extra nodes, 0 pruned nodes, max_depth=58
# [14]	validation-rmse:5854.32757
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5924 extra nodes, 0 pruned nodes, max_depth=66
# [15]	validation-rmse:5853.93367
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5988 extra nodes, 0 pruned nodes, max_depth=72
# [16]	validation-rmse:5853.77916
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5916 extra nodes, 0 pruned nodes, max_depth=72
# [17]	validation-rmse:5853.66240
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4840 extra nodes, 0 pruned nodes, max_depth=72
# [18]	validation-rmse:5853.62877
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4838 extra nodes, 0 pruned nodes, max_depth=72
# [19]	validation-rmse:5853.58506
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4514 extra nodes, 0 pruned nodes, max_depth=72
# [20]	validation-rmse:5853.57647
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3386 extra nodes, 0 pruned nodes, max_depth=72
# [21]	validation-rmse:5853.56133
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3560 extra nodes, 0 pruned nodes, max_depth=61
# [22]	validation-rmse:5853.55214
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3316 extra nodes, 0 pruned nodes, max_depth=70
# [23]	validation-rmse:5853.55060
# [03:49:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3058 extra nodes, 0 pruned nodes, max_depth=50
# [24]	validation-rmse:5853.55072
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2912 extra nodes, 0 pruned nodes, max_depth=72
# [25]	validation-rmse:5853.53165
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2526 extra nodes, 0 pruned nodes, max_depth=72
# [26]	validation-rmse:5853.53148
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2478 extra nodes, 0 pruned nodes, max_depth=70
# [27]	validation-rmse:5853.53079
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2428 extra nodes, 0 pruned nodes, max_depth=49
# [28]	validation-rmse:5853.53017
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2308 extra nodes, 0 pruned nodes, max_depth=60
# [29]	validation-rmse:5853.52997
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1846 extra nodes, 0 pruned nodes, max_depth=36
# [30]	validation-rmse:5853.52977
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1974 extra nodes, 0 pruned nodes, max_depth=52
# [31]	validation-rmse:5853.52725
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1764 extra nodes, 0 pruned nodes, max_depth=48
# [32]	validation-rmse:5853.52710
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1836 extra nodes, 0 pruned nodes, max_depth=32
# [33]	validation-rmse:5853.52699
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1618 extra nodes, 0 pruned nodes, max_depth=72
# [34]	validation-rmse:5853.52699
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1556 extra nodes, 0 pruned nodes, max_depth=60
# [35]	validation-rmse:5853.52699
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1516 extra nodes, 0 pruned nodes, max_depth=46
# [36]	validation-rmse:5853.52690
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1590 extra nodes, 0 pruned nodes, max_depth=49
# [37]	validation-rmse:5853.52690
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1342 extra nodes, 0 pruned nodes, max_depth=37
# [38]	validation-rmse:5853.52685
# [03:49:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1368 extra nodes, 0 pruned nodes, max_depth=60
# [39]	validation-rmse:5853.52679
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1252 extra nodes, 0 pruned nodes, max_depth=33
# [40]	validation-rmse:5853.52670
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1228 extra nodes, 0 pruned nodes, max_depth=46
# [41]	validation-rmse:5853.52603
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1258 extra nodes, 0 pruned nodes, max_depth=47
# [42]	validation-rmse:5853.52526
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1218 extra nodes, 0 pruned nodes, max_depth=44
# [43]	validation-rmse:5853.52517
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1186 extra nodes, 0 pruned nodes, max_depth=35
# [44]	validation-rmse:5853.52517
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1218 extra nodes, 0 pruned nodes, max_depth=36
# [45]	validation-rmse:5853.52514
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1016 extra nodes, 0 pruned nodes, max_depth=39
# [46]	validation-rmse:5853.52511
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1042 extra nodes, 0 pruned nodes, max_depth=43
# [47]	validation-rmse:5853.52511
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1002 extra nodes, 0 pruned nodes, max_depth=27
# [48]	validation-rmse:5853.52511
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1000 extra nodes, 0 pruned nodes, max_depth=31
# [49]	validation-rmse:5853.52510
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 996 extra nodes, 0 pruned nodes, max_depth=42
# [50]	validation-rmse:5853.52510
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1000 extra nodes, 0 pruned nodes, max_depth=27
# [51]	validation-rmse:5853.52431
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 996 extra nodes, 0 pruned nodes, max_depth=36
# [52]	validation-rmse:5853.52432
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 918 extra nodes, 0 pruned nodes, max_depth=36
# [53]	validation-rmse:5853.52393
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 958 extra nodes, 0 pruned nodes, max_depth=38
# [54]	validation-rmse:5853.52383
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 964 extra nodes, 0 pruned nodes, max_depth=49
# [55]	validation-rmse:5853.52384
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 840 extra nodes, 0 pruned nodes, max_depth=27
# [56]	validation-rmse:5853.52383
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 982 extra nodes, 0 pruned nodes, max_depth=40
# [57]	validation-rmse:5853.52384
# [03:49:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 878 extra nodes, 0 pruned nodes, max_depth=25
# [58]	validation-rmse:5853.52383
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 866 extra nodes, 0 pruned nodes, max_depth=30
# [59]	validation-rmse:5853.52373
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 848 extra nodes, 0 pruned nodes, max_depth=26
# [60]	validation-rmse:5853.52373
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 716 extra nodes, 0 pruned nodes, max_depth=30
# [61]	validation-rmse:5853.52373
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 774 extra nodes, 0 pruned nodes, max_depth=30
# [62]	validation-rmse:5853.52372
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 750 extra nodes, 0 pruned nodes, max_depth=28
# [63]	validation-rmse:5853.52372
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 802 extra nodes, 0 pruned nodes, max_depth=28
# [64]	validation-rmse:5853.52364
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 738 extra nodes, 0 pruned nodes, max_depth=28
# [65]	validation-rmse:5853.52364
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 768 extra nodes, 0 pruned nodes, max_depth=24
# [66]	validation-rmse:5853.52363
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 722 extra nodes, 0 pruned nodes, max_depth=30
# [67]	validation-rmse:5853.52354
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 696 extra nodes, 0 pruned nodes, max_depth=29
# [68]	validation-rmse:5853.52353
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 626 extra nodes, 0 pruned nodes, max_depth=22
# [69]	validation-rmse:5853.52353
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 710 extra nodes, 0 pruned nodes, max_depth=25
# [70]	validation-rmse:5853.52342
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 612 extra nodes, 0 pruned nodes, max_depth=35
# [71]	validation-rmse:5853.52342
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 734 extra nodes, 0 pruned nodes, max_depth=26
# [72]	validation-rmse:5853.52342
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 778 extra nodes, 0 pruned nodes, max_depth=35
# [73]	validation-rmse:5853.52340
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 666 extra nodes, 0 pruned nodes, max_depth=23
# [74]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 462 extra nodes, 0 pruned nodes, max_depth=23
# [75]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 760 extra nodes, 0 pruned nodes, max_depth=26
# [76]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 608 extra nodes, 0 pruned nodes, max_depth=20
# [77]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 698 extra nodes, 0 pruned nodes, max_depth=28
# [78]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 546 extra nodes, 0 pruned nodes, max_depth=36
# [79]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 698 extra nodes, 0 pruned nodes, max_depth=24
# [80]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 606 extra nodes, 0 pruned nodes, max_depth=28
# [81]	validation-rmse:5853.52341
# [03:49:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 614 extra nodes, 0 pruned nodes, max_depth=26
# [82]	validation-rmse:5853.52341
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 560 extra nodes, 0 pruned nodes, max_depth=26
# [83]	validation-rmse:5853.52341
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 676 extra nodes, 0 pruned nodes, max_depth=31
# [84]	validation-rmse:5853.52337
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 586 extra nodes, 0 pruned nodes, max_depth=25
# [85]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 626 extra nodes, 0 pruned nodes, max_depth=22
# [86]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 532 extra nodes, 0 pruned nodes, max_depth=17
# [87]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 580 extra nodes, 0 pruned nodes, max_depth=25
# [88]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 604 extra nodes, 0 pruned nodes, max_depth=21
# [89]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 588 extra nodes, 0 pruned nodes, max_depth=28
# [90]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 544 extra nodes, 0 pruned nodes, max_depth=26
# [91]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 612 extra nodes, 0 pruned nodes, max_depth=37
# [92]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 564 extra nodes, 0 pruned nodes, max_depth=30
# [93]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 544 extra nodes, 0 pruned nodes, max_depth=26
# [94]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 444 extra nodes, 0 pruned nodes, max_depth=18
# [95]	validation-rmse:5853.52338
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 516 extra nodes, 0 pruned nodes, max_depth=26
# [96]	validation-rmse:5853.52334
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 518 extra nodes, 0 pruned nodes, max_depth=24
# [97]	validation-rmse:5853.52334
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 470 extra nodes, 0 pruned nodes, max_depth=21
# [98]	validation-rmse:5853.52334
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 474 extra nodes, 0 pruned nodes, max_depth=22
# [99]	validation-rmse:5853.52334
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 496 extra nodes, 0 pruned nodes, max_depth=25
# [100]	validation-rmse:5853.52334
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 430 extra nodes, 0 pruned nodes, max_depth=29
# [101]	validation-rmse:5853.52334
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 536 extra nodes, 0 pruned nodes, max_depth=27
# [102]	validation-rmse:5853.52256
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 432 extra nodes, 0 pruned nodes, max_depth=29
# [103]	validation-rmse:5853.52256
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 448 extra nodes, 0 pruned nodes, max_depth=23
# [104]	validation-rmse:5853.52256
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 382 extra nodes, 0 pruned nodes, max_depth=31
# [105]	validation-rmse:5853.52256
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 454 extra nodes, 0 pruned nodes, max_depth=19
# [106]	validation-rmse:5853.52256
# [03:49:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 506 extra nodes, 0 pruned nodes, max_depth=22
# [107]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 506 extra nodes, 0 pruned nodes, max_depth=24
# [108]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 384 extra nodes, 0 pruned nodes, max_depth=21
# [109]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 500 extra nodes, 0 pruned nodes, max_depth=22
# [110]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 434 extra nodes, 0 pruned nodes, max_depth=18
# [111]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 414 extra nodes, 0 pruned nodes, max_depth=19
# [112]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 442 extra nodes, 0 pruned nodes, max_depth=22
# [113]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 420 extra nodes, 0 pruned nodes, max_depth=27
# [114]	validation-rmse:5853.52256
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 430 extra nodes, 0 pruned nodes, max_depth=19
# [115]	validation-rmse:5853.52257
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 460 extra nodes, 0 pruned nodes, max_depth=20
# [116]	validation-rmse:5853.52253
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 444 extra nodes, 0 pruned nodes, max_depth=21
# [117]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 434 extra nodes, 0 pruned nodes, max_depth=24
# [118]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 442 extra nodes, 0 pruned nodes, max_depth=24
# [119]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 498 extra nodes, 0 pruned nodes, max_depth=19
# [120]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 472 extra nodes, 0 pruned nodes, max_depth=18
# [121]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 358 extra nodes, 0 pruned nodes, max_depth=23
# [122]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 390 extra nodes, 0 pruned nodes, max_depth=20
# [123]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 446 extra nodes, 0 pruned nodes, max_depth=18
# [124]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 356 extra nodes, 0 pruned nodes, max_depth=22
# [125]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 484 extra nodes, 0 pruned nodes, max_depth=28
# [126]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 436 extra nodes, 0 pruned nodes, max_depth=30
# [127]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 426 extra nodes, 0 pruned nodes, max_depth=19
# [128]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 422 extra nodes, 0 pruned nodes, max_depth=19
# [129]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 468 extra nodes, 0 pruned nodes, max_depth=20
# [130]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 304 extra nodes, 0 pruned nodes, max_depth=25
# [131]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 398 extra nodes, 0 pruned nodes, max_depth=22
# [132]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 328 extra nodes, 0 pruned nodes, max_depth=18
# [133]	validation-rmse:5853.52252
# [03:49:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 462 extra nodes, 0 pruned nodes, max_depth=22
# [134]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 452 extra nodes, 0 pruned nodes, max_depth=22
# [135]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 372 extra nodes, 0 pruned nodes, max_depth=18
# [136]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 354 extra nodes, 0 pruned nodes, max_depth=21
# [137]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 326 extra nodes, 0 pruned nodes, max_depth=15
# [138]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 392 extra nodes, 0 pruned nodes, max_depth=22
# [139]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 408 extra nodes, 0 pruned nodes, max_depth=18
# [140]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 348 extra nodes, 0 pruned nodes, max_depth=17
# [141]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 394 extra nodes, 0 pruned nodes, max_depth=20
# [142]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 346 extra nodes, 0 pruned nodes, max_depth=19
# [143]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 280 extra nodes, 0 pruned nodes, max_depth=23
# [144]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 358 extra nodes, 0 pruned nodes, max_depth=20
# [145]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 378 extra nodes, 0 pruned nodes, max_depth=18
# [146]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 316 extra nodes, 0 pruned nodes, max_depth=21
# [147]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 238 extra nodes, 0 pruned nodes, max_depth=14
# [148]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 274 extra nodes, 0 pruned nodes, max_depth=17
# [149]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 362 extra nodes, 0 pruned nodes, max_depth=19
# [150]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 348 extra nodes, 0 pruned nodes, max_depth=20
# [151]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 374 extra nodes, 0 pruned nodes, max_depth=20
# [152]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 452 extra nodes, 0 pruned nodes, max_depth=28
# [153]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=19
# [154]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 308 extra nodes, 0 pruned nodes, max_depth=23
# [155]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 298 extra nodes, 0 pruned nodes, max_depth=22
# [156]	validation-rmse:5853.52249
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 302 extra nodes, 0 pruned nodes, max_depth=19
# [157]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 234 extra nodes, 0 pruned nodes, max_depth=19
# [158]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 324 extra nodes, 0 pruned nodes, max_depth=15
# [159]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 282 extra nodes, 0 pruned nodes, max_depth=27
# [160]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 266 extra nodes, 0 pruned nodes, max_depth=19
# [161]	validation-rmse:5853.52252
# [03:49:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 248 extra nodes, 0 pruned nodes, max_depth=19
# [162]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 380 extra nodes, 0 pruned nodes, max_depth=26
# [163]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 262 extra nodes, 0 pruned nodes, max_depth=20
# [164]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 346 extra nodes, 0 pruned nodes, max_depth=18
# [165]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 294 extra nodes, 0 pruned nodes, max_depth=18
# [166]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 230 extra nodes, 0 pruned nodes, max_depth=20
# [167]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 252 extra nodes, 0 pruned nodes, max_depth=15
# [168]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 348 extra nodes, 0 pruned nodes, max_depth=17
# [169]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 248 extra nodes, 0 pruned nodes, max_depth=18
# [170]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 270 extra nodes, 0 pruned nodes, max_depth=20
# [171]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 216 extra nodes, 0 pruned nodes, max_depth=26
# [172]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 240 extra nodes, 0 pruned nodes, max_depth=20
# [173]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 266 extra nodes, 0 pruned nodes, max_depth=18
# [174]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 260 extra nodes, 0 pruned nodes, max_depth=17
# [175]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=19
# [176]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 138 extra nodes, 0 pruned nodes, max_depth=13
# [177]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 194 extra nodes, 0 pruned nodes, max_depth=15
# [178]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 88 extra nodes, 0 pruned nodes, max_depth=12
# [179]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 114 extra nodes, 0 pruned nodes, max_depth=11
# [180]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=14
# [181]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 46 extra nodes, 0 pruned nodes, max_depth=11
# [182]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 136 extra nodes, 0 pruned nodes, max_depth=13
# [183]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 62 extra nodes, 0 pruned nodes, max_depth=11
# [184]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 44 extra nodes, 0 pruned nodes, max_depth=9
# [185]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 176 extra nodes, 0 pruned nodes, max_depth=17
# [186]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 176 extra nodes, 0 pruned nodes, max_depth=21
# [187]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 270 extra nodes, 0 pruned nodes, max_depth=25
# [188]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 222 extra nodes, 0 pruned nodes, max_depth=16
# [189]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 328 extra nodes, 0 pruned nodes, max_depth=18
# [190]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 270 extra nodes, 0 pruned nodes, max_depth=17
# [191]	validation-rmse:5853.52252
# [03:49:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 320 extra nodes, 0 pruned nodes, max_depth=21
# [03:49:22] ======== Monitor (0): Learner ========
# [03:49:22] Configure: 0.095233s, 1 calls @ 95233us
#
# [03:49:22] EvalOneIter: 0.183945s, 193 calls @ 183945us
#
# [03:49:22] GetGradient: 0.015018s, 193 calls @ 15018us
#
# [03:49:22] PredictRaw: 0.303764s, 193 calls @ 303764us
#
# [03:49:22] UpdateOneIter: 7.43055s, 193 calls @ 7430552us
#
# [03:49:22] ======== Monitor (0): GBTree ========
# [03:49:22] BoostNewTrees: 7.09625s, 193 calls @ 7096249us
#
# [03:49:22] CommitModel: 0.000293s, 193 calls @ 293us
#
# [03:49:22] ======== Monitor (0): TreePruner ========
# [03:49:22] PrunerUpdate: 1.46037s, 193 calls @ 1460370us
#
# default artifacts URI: 's3://mlflow-artifacts-remote-zoomcamp/1/75fb4c2cb1384a0aabc73fbcbeb0f9f1/artifacts'
# [03:49:30] ======== Monitor (0): Learner ========
# [03:49:30] Configure: 0.000526s, 1 calls @ 526us
#
# [03:49:30] ======== Monitor (0): GBTree ========
# [03:49:30] ======== Monitor (0): TreePruner ========
# default artifacts URI: 's3://mlflow-artifacts-remote-zoomcamp/1/7f19f582bab4466b9a2d24004e753446/artifacts'
# [03:49:30] DEBUG: ../src/gbm/gbtree.cc:157: Using tree method: 2
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 80 extra nodes, 0 pruned nodes, max_depth=7
# [0]	validation-rmse:10022.68239
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 82 extra nodes, 0 pruned nodes, max_depth=8
# [1]	validation-rmse:7629.61006
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 150 extra nodes, 0 pruned nodes, max_depth=10
# [2]	validation-rmse:6630.27510
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 290 extra nodes, 0 pruned nodes, max_depth=12
# [3]	validation-rmse:6202.81204
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 516 extra nodes, 0 pruned nodes, max_depth=14
# [4]	validation-rmse:6015.66175
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1024 extra nodes, 0 pruned nodes, max_depth=22
# [5]	validation-rmse:5930.96899
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1982 extra nodes, 0 pruned nodes, max_depth=24
# [6]	validation-rmse:5892.08756
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3538 extra nodes, 0 pruned nodes, max_depth=28
# [7]	validation-rmse:5873.25812
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5774 extra nodes, 0 pruned nodes, max_depth=38
# [8]	validation-rmse:5863.83119
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 7486 extra nodes, 0 pruned nodes, max_depth=40
# [9]	validation-rmse:5859.08210
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 8836 extra nodes, 0 pruned nodes, max_depth=57
# [10]	validation-rmse:5856.56126
# [03:49:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 9204 extra nodes, 0 pruned nodes, max_depth=54
# [11]	validation-rmse:5855.03442
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 9234 extra nodes, 0 pruned nodes, max_depth=59
# [12]	validation-rmse:5854.17649
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 8646 extra nodes, 0 pruned nodes, max_depth=58
# [13]	validation-rmse:5853.73384
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 8158 extra nodes, 0 pruned nodes, max_depth=68
# [14]	validation-rmse:5853.53985
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 7326 extra nodes, 0 pruned nodes, max_depth=78
# [15]	validation-rmse:5853.40490
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6810 extra nodes, 0 pruned nodes, max_depth=74
# [16]	validation-rmse:5853.33602
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5832 extra nodes, 0 pruned nodes, max_depth=83
# [17]	validation-rmse:5853.30745
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5036 extra nodes, 0 pruned nodes, max_depth=83
# [18]	validation-rmse:5853.29669
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4886 extra nodes, 0 pruned nodes, max_depth=63
# [19]	validation-rmse:5853.29322
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4096 extra nodes, 0 pruned nodes, max_depth=73
# [20]	validation-rmse:5853.29284
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3766 extra nodes, 0 pruned nodes, max_depth=81
# [21]	validation-rmse:5853.29273
# [03:49:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3324 extra nodes, 0 pruned nodes, max_depth=84
# [22]	validation-rmse:5853.29276
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3014 extra nodes, 0 pruned nodes, max_depth=58
# [23]	validation-rmse:5853.29281
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2822 extra nodes, 0 pruned nodes, max_depth=53
# [24]	validation-rmse:5853.29264
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2592 extra nodes, 0 pruned nodes, max_depth=56
# [25]	validation-rmse:5853.29185
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2416 extra nodes, 0 pruned nodes, max_depth=44
# [26]	validation-rmse:5853.29184
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2062 extra nodes, 0 pruned nodes, max_depth=44
# [27]	validation-rmse:5853.29184
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2134 extra nodes, 0 pruned nodes, max_depth=67
# [28]	validation-rmse:5853.29173
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1848 extra nodes, 0 pruned nodes, max_depth=51
# [29]	validation-rmse:5853.29173
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1644 extra nodes, 0 pruned nodes, max_depth=42
# [30]	validation-rmse:5853.29175
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1498 extra nodes, 0 pruned nodes, max_depth=41
# [31]	validation-rmse:5853.29172
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1530 extra nodes, 0 pruned nodes, max_depth=43
# [32]	validation-rmse:5853.29213
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1392 extra nodes, 0 pruned nodes, max_depth=45
# [33]	validation-rmse:5853.29213
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1270 extra nodes, 0 pruned nodes, max_depth=47
# [34]	validation-rmse:5853.29213
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1212 extra nodes, 0 pruned nodes, max_depth=46
# [35]	validation-rmse:5853.29173
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1142 extra nodes, 0 pruned nodes, max_depth=30
# [36]	validation-rmse:5853.29174
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=42
# [37]	validation-rmse:5853.29174
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 932 extra nodes, 0 pruned nodes, max_depth=30
# [38]	validation-rmse:5853.29170
# [03:49:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 868 extra nodes, 0 pruned nodes, max_depth=35
# [39]	validation-rmse:5853.29170
# [03:49:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 712 extra nodes, 0 pruned nodes, max_depth=32
# [40]	validation-rmse:5853.29170
# [03:49:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 926 extra nodes, 0 pruned nodes, max_depth=56
# [41]	validation-rmse:5853.29170
# [03:49:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 692 extra nodes, 0 pruned nodes, max_depth=23
# [42]	validation-rmse:5853.29169
# [03:49:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 732 extra nodes, 0 pruned nodes, max_depth=31
# [43]	validation-rmse:5853.29169
# [03:49:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 650 extra nodes, 0 pruned nodes, max_depth=22
# ...
# [139]	validation-rmse:5853.37344
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 7032 extra nodes, 0 pruned nodes, max_depth=94
# [140]	validation-rmse:5853.37186
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5092 extra nodes, 0 pruned nodes, max_depth=113
# [141]	validation-rmse:5853.37018
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5646 extra nodes, 0 pruned nodes, max_depth=93
# [142]	validation-rmse:5853.36802
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4784 extra nodes, 0 pruned nodes, max_depth=93
# [143]	validation-rmse:5853.36583
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4864 extra nodes, 0 pruned nodes, max_depth=106
# [144]	validation-rmse:5853.36423
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6234 extra nodes, 0 pruned nodes, max_depth=85
# [145]	validation-rmse:5853.36379
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6500 extra nodes, 0 pruned nodes, max_depth=113
# [146]	validation-rmse:5853.36222
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6834 extra nodes, 0 pruned nodes, max_depth=113
# [147]	validation-rmse:5853.36071
# [03:49:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6394 extra nodes, 0 pruned nodes, max_depth=111
# [148]	validation-rmse:5853.35914
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6344 extra nodes, 0 pruned nodes, max_depth=96
# [149]	validation-rmse:5853.35800
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6068 extra nodes, 0 pruned nodes, max_depth=113
# [150]	validation-rmse:5853.35716
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6256 extra nodes, 0 pruned nodes, max_depth=113
# [151]	validation-rmse:5853.35631
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4716 extra nodes, 0 pruned nodes, max_depth=90
# [152]	validation-rmse:5853.35547
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6464 extra nodes, 0 pruned nodes, max_depth=113
# [153]	validation-rmse:5853.35463
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3010 extra nodes, 0 pruned nodes, max_depth=75
# [154]	validation-rmse:5853.35378
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3840 extra nodes, 0 pruned nodes, max_depth=113
# [155]	validation-rmse:5853.35295
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6664 extra nodes, 0 pruned nodes, max_depth=113
# [156]	validation-rmse:5853.35294
# [03:49:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5842 extra nodes, 0 pruned nodes, max_depth=113
# [157]	validation-rmse:5853.35210
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6560 extra nodes, 0 pruned nodes, max_depth=107
# [158]	validation-rmse:5853.35203
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5392 extra nodes, 0 pruned nodes, max_depth=113
# [159]	validation-rmse:5853.35119
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6266 extra nodes, 0 pruned nodes, max_depth=113
# [160]	validation-rmse:5853.35037
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5886 extra nodes, 0 pruned nodes, max_depth=113
# [161]	validation-rmse:5853.34954
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3610 extra nodes, 0 pruned nodes, max_depth=113
# [162]	validation-rmse:5853.34870
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6114 extra nodes, 0 pruned nodes, max_depth=99
# [163]	validation-rmse:5853.34793
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4526 extra nodes, 0 pruned nodes, max_depth=113
# [164]	validation-rmse:5853.34793
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4310 extra nodes, 0 pruned nodes, max_depth=113
# [165]	validation-rmse:5853.34793
# [03:49:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4128 extra nodes, 0 pruned nodes, max_depth=92
# [166]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3744 extra nodes, 0 pruned nodes, max_depth=113
# [167]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4216 extra nodes, 0 pruned nodes, max_depth=109
# [168]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3956 extra nodes, 0 pruned nodes, max_depth=113
# [169]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2368 extra nodes, 0 pruned nodes, max_depth=85
# [170]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3242 extra nodes, 0 pruned nodes, max_depth=84
# [171]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2802 extra nodes, 0 pruned nodes, max_depth=87
# [172]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1972 extra nodes, 0 pruned nodes, max_depth=71
# [173]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1606 extra nodes, 0 pruned nodes, max_depth=60
# [174]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1636 extra nodes, 0 pruned nodes, max_depth=44
# [175]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1544 extra nodes, 0 pruned nodes, max_depth=54
# [176]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1898 extra nodes, 0 pruned nodes, max_depth=66
# [177]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2196 extra nodes, 0 pruned nodes, max_depth=77
# [178]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2180 extra nodes, 0 pruned nodes, max_depth=70
# [179]	validation-rmse:5853.34793
# [03:49:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2006 extra nodes, 0 pruned nodes, max_depth=87
# [180]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1926 extra nodes, 0 pruned nodes, max_depth=62
# [181]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1898 extra nodes, 0 pruned nodes, max_depth=54
# [182]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1926 extra nodes, 0 pruned nodes, max_depth=59
# [183]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1736 extra nodes, 0 pruned nodes, max_depth=57
# [184]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1620 extra nodes, 0 pruned nodes, max_depth=59
# [185]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1696 extra nodes, 0 pruned nodes, max_depth=56
# [186]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1638 extra nodes, 0 pruned nodes, max_depth=58
# [187]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1700 extra nodes, 0 pruned nodes, max_depth=39
# [188]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1544 extra nodes, 0 pruned nodes, max_depth=38
# [189]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1550 extra nodes, 0 pruned nodes, max_depth=40
# [190]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1564 extra nodes, 0 pruned nodes, max_depth=37
# [191]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1450 extra nodes, 0 pruned nodes, max_depth=43
# [192]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1508 extra nodes, 0 pruned nodes, max_depth=51
# [193]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1518 extra nodes, 0 pruned nodes, max_depth=42
# [194]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1440 extra nodes, 0 pruned nodes, max_depth=39
# [195]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1356 extra nodes, 0 pruned nodes, max_depth=38
# [196]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1420 extra nodes, 0 pruned nodes, max_depth=34
# [197]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1372 extra nodes, 0 pruned nodes, max_depth=68
# [198]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1476 extra nodes, 0 pruned nodes, max_depth=84
# [199]	validation-rmse:5853.34793
# [03:49:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1406 extra nodes, 0 pruned nodes, max_depth=89
# [200]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1288 extra nodes, 0 pruned nodes, max_depth=47
# [201]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1264 extra nodes, 0 pruned nodes, max_depth=38
# [202]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1266 extra nodes, 0 pruned nodes, max_depth=52
# [203]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1290 extra nodes, 0 pruned nodes, max_depth=69
# [204]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1220 extra nodes, 0 pruned nodes, max_depth=57
# [205]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1282 extra nodes, 0 pruned nodes, max_depth=64
# [206]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1102 extra nodes, 0 pruned nodes, max_depth=53
# [207]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1066 extra nodes, 0 pruned nodes, max_depth=71
# [208]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1034 extra nodes, 0 pruned nodes, max_depth=38
# [209]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1170 extra nodes, 0 pruned nodes, max_depth=62
# [210]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 882 extra nodes, 0 pruned nodes, max_depth=38
# [211]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 922 extra nodes, 0 pruned nodes, max_depth=40
# [212]	validation-rmse:5853.34793
# [03:49:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 728 extra nodes, 0 pruned nodes, max_depth=33
# [213]	validation-rmse:5853.34793
# [03:49:57] ======== Monitor (0): Learner ========
# [03:49:57] Configure: 0.007144s, 1 calls @ 7144us
#
# [03:49:57] EvalOneIter: 0.205228s, 214 calls @ 205228us
#
# [03:49:57] GetGradient: 0.009478s, 214 calls @ 9478us
#
# [03:49:57] PredictRaw: 0.405238s, 214 calls @ 405238us
#
# [03:49:57] UpdateOneIter: 10.9232s, 214 calls @ 10923214us
#
# [03:49:57] ======== Monitor (0): GBTree ========
# [03:49:57] BoostNewTrees: 10.4963s, 214 calls @ 10496255us
#
# [03:49:57] CommitModel: 0.000308s, 214 calls @ 308us
#
# [03:49:57] ======== Monitor (0): TreePruner ========
# [03:49:57] PrunerUpdate: 1.66382s, 214 calls @ 1663815us
#
# default artifacts URI: 's3://mlflow-artifacts-remote-zoomcamp/1/4899d56c1b8b490a98b37f416af79f99/artifacts'
# [03:50:05] ======== Monitor (0): Learner ========
# [03:50:05] Configure: 0.000559s, 1 calls @ 559us
#
# [03:50:05] ======== Monitor (0): GBTree ========
# [03:50:05] ======== Monitor (0): TreePruner ========
# 100%|████████████| 3/3 [00:56<00:00, 18.74s/trial, best loss: 5853.291686840538]

# %%
# Test using the best result

# Make sure AWS credentials are set properly
# Either using environment variables or ~/.aws/credentials
os.environ["AWS_PROFILE"] = "default" # fill in with your AWS profile. More info: https://docs.aws.amazon.com/sdk-for-java/latest/developer-guide/setup.html#setup-credentials

TRACKING_SERVER_HOST = "ec2-13-251-63-107.ap-southeast-1.compute.amazonaws.com" # fill in with the public DNS of the EC2 instance

# create a connection to S3
fs = s3fs.S3FileSystem()

# use a local tracking server
mlflow.set_tracking_uri("file:///tmp/mlruns")

with mlflow.start_run(experiment_id="0"):
    
    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.09585355369315604,
        'max_depth': 30,
        'min_child_weight': 1.060597050922164,
        'objective': 'reg:squarederror',
        'reg_alpha': 0.018060244040060163,
        'reg_lambda': 0.011658731377413597,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)
    rmse = mean_squared_error(y_val, y_pred, squared=False)
    mlflow.log_metric("rmse", rmse)
    
    error_percentage = rmse / range * 100
    mlflow.log_metric("error_percentage", error_percentage)

    # Save model locally
    mlflow.xgboost.save_model(booster, "/tmp/models_mlflow")

    # Save the preprocessor locally
    with open("/tmp/preprocessor.pkl", "wb") as f_out:
        pickle.dump(dv, f_out)

    # Upload model and preprocessor to S3
    fs.put("/tmp/preprocessor.pkl", "s3://mlflow-artifacts-remote-zoomcamp/mlruns/preprocessor.pkl")
    fs.put("/tmp/models_mlflow", "s3://mlflow-artifacts-remote-zoomcamp/mlruns/model.xgb")

    # Log artifacts paths to mlflow
    mlflow.log_artifact("/tmp/preprocessor2.pkl", artifact_path="preprocessor")
    mlflow.log_artifact("/tmp/models_mlflow2", artifact_path="models_mlflow")
    
    
    print(f"default artifacts URI: '{mlflow.get_artifact_uri()}'")
# Out:
# [13:03:44] DEBUG: ../src/gbm/gbtree.cc:157: Using tree method: 2
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [0]	validation-rmse:14732.65596
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 216 extra nodes, 0 pruned nodes, max_depth=9
# [1]	validation-rmse:13859.59647
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [2]	validation-rmse:13074.57000
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=9
# [3]	validation-rmse:12363.43208
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 212 extra nodes, 0 pruned nodes, max_depth=9
# [4]	validation-rmse:11725.20722
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 214 extra nodes, 0 pruned nodes, max_depth=9
# [5]	validation-rmse:11146.79106
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [6]	validation-rmse:10627.70042
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 212 extra nodes, 0 pruned nodes, max_depth=9
# [7]	validation-rmse:10157.64701
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 214 extra nodes, 0 pruned nodes, max_depth=9
# [8]	validation-rmse:9735.72185
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [9]	validation-rmse:9358.16890
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=9
# [10]	validation-rmse:9014.30087
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 212 extra nodes, 0 pruned nodes, max_depth=9
# [11]	validation-rmse:8704.16675
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=9
# [12]	validation-rmse:8428.10358
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 214 extra nodes, 0 pruned nodes, max_depth=9
# [13]	validation-rmse:8176.18357
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [14]	validation-rmse:7951.17641
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 214 extra nodes, 0 pruned nodes, max_depth=9
# [15]	validation-rmse:7746.35143
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 216 extra nodes, 0 pruned nodes, max_depth=9
# [16]	validation-rmse:7563.46024
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=9
# [17]	validation-rmse:7397.42056
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [18]	validation-rmse:7247.48811
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 214 extra nodes, 0 pruned nodes, max_depth=9
# [19]	validation-rmse:7113.58790
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 214 extra nodes, 0 pruned nodes, max_depth=10
# [20]	validation-rmse:6991.59136
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 206 extra nodes, 0 pruned nodes, max_depth=10
# [21]	validation-rmse:6881.75894
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 206 extra nodes, 0 pruned nodes, max_depth=9
# [22]	validation-rmse:6783.47424
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [23]	validation-rmse:6693.84620
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 212 extra nodes, 0 pruned nodes, max_depth=9
# [24]	validation-rmse:6613.92075
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 204 extra nodes, 0 pruned nodes, max_depth=9
# [25]	validation-rmse:6541.07206
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 218 extra nodes, 0 pruned nodes, max_depth=9
# [26]	validation-rmse:6475.17837
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 216 extra nodes, 0 pruned nodes, max_depth=9
# [27]	validation-rmse:6415.66636
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 216 extra nodes, 0 pruned nodes, max_depth=9
# [28]	validation-rmse:6362.92450
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 216 extra nodes, 0 pruned nodes, max_depth=9
# [29]	validation-rmse:6314.27602
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 206 extra nodes, 0 pruned nodes, max_depth=9
# [30]	validation-rmse:6270.29597
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=9
# [31]	validation-rmse:6231.21898
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 206 extra nodes, 0 pruned nodes, max_depth=9
# [32]	validation-rmse:6195.42662
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=10
# [33]	validation-rmse:6163.24242
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 212 extra nodes, 0 pruned nodes, max_depth=9
# [34]	validation-rmse:6134.26123
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 206 extra nodes, 0 pruned nodes, max_depth=9
# [35]	validation-rmse:6107.63144
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=10
# [36]	validation-rmse:6084.21807
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 212 extra nodes, 0 pruned nodes, max_depth=10
# [37]	validation-rmse:6062.46857
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 210 extra nodes, 0 pruned nodes, max_depth=9
# [38]	validation-rmse:6042.70931
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 212 extra nodes, 0 pruned nodes, max_depth=9
# [39]	validation-rmse:6024.97875
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 208 extra nodes, 0 pruned nodes, max_depth=9
# [40]	validation-rmse:6008.87331
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 226 extra nodes, 0 pruned nodes, max_depth=10
# [41]	validation-rmse:5994.65596
# [13:03:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 222 extra nodes, 0 pruned nodes, max_depth=10
# [42]	validation-rmse:5981.56644
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 240 extra nodes, 0 pruned nodes, max_depth=11
# [43]	validation-rmse:5969.49550
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 284 extra nodes, 0 pruned nodes, max_depth=12
# [44]	validation-rmse:5958.61854
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 292 extra nodes, 0 pruned nodes, max_depth=11
# [45]	validation-rmse:5948.81732
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 386 extra nodes, 0 pruned nodes, max_depth=13
# [46]	validation-rmse:5940.16049
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 396 extra nodes, 0 pruned nodes, max_depth=14
# [47]	validation-rmse:5932.03305
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 564 extra nodes, 0 pruned nodes, max_depth=14
# [48]	validation-rmse:5924.64773
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 622 extra nodes, 0 pruned nodes, max_depth=15
# [49]	validation-rmse:5918.05609
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 944 extra nodes, 0 pruned nodes, max_depth=20
# [50]	validation-rmse:5912.04404
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1060 extra nodes, 0 pruned nodes, max_depth=16
# [51]	validation-rmse:5906.79203
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1384 extra nodes, 0 pruned nodes, max_depth=18
# [52]	validation-rmse:5902.00421
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1624 extra nodes, 0 pruned nodes, max_depth=20
# [53]	validation-rmse:5897.46121
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1828 extra nodes, 0 pruned nodes, max_depth=21
# [54]	validation-rmse:5893.38517
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2188 extra nodes, 0 pruned nodes, max_depth=20
# [55]	validation-rmse:5889.66759
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2600 extra nodes, 0 pruned nodes, max_depth=22
# [56]	validation-rmse:5886.39528
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2758 extra nodes, 0 pruned nodes, max_depth=21
# [57]	validation-rmse:5883.30861
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3138 extra nodes, 0 pruned nodes, max_depth=26
# [58]	validation-rmse:5880.60854
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3444 extra nodes, 0 pruned nodes, max_depth=28
# [59]	validation-rmse:5878.07528
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3802 extra nodes, 0 pruned nodes, max_depth=29
# [60]	validation-rmse:5875.81348
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3900 extra nodes, 0 pruned nodes, max_depth=27
# [61]	validation-rmse:5873.73859
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4228 extra nodes, 0 pruned nodes, max_depth=30
# [62]	validation-rmse:5871.82438
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4404 extra nodes, 0 pruned nodes, max_depth=28
# [63]	validation-rmse:5870.20839
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4730 extra nodes, 0 pruned nodes, max_depth=30
# [64]	validation-rmse:5868.63139
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4708 extra nodes, 0 pruned nodes, max_depth=30
# [65]	validation-rmse:5867.20478
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4802 extra nodes, 0 pruned nodes, max_depth=30
# [66]	validation-rmse:5865.99858
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5070 extra nodes, 0 pruned nodes, max_depth=30
# [67]	validation-rmse:5864.84564
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4966 extra nodes, 0 pruned nodes, max_depth=30
# [68]	validation-rmse:5863.82950
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5136 extra nodes, 0 pruned nodes, max_depth=30
# [69]	validation-rmse:5862.91047
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5308 extra nodes, 0 pruned nodes, max_depth=30
# [70]	validation-rmse:5862.05308
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5390 extra nodes, 0 pruned nodes, max_depth=30
# [71]	validation-rmse:5861.25312
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5226 extra nodes, 0 pruned nodes, max_depth=30
# [72]	validation-rmse:5860.52998
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5340 extra nodes, 0 pruned nodes, max_depth=30
# [73]	validation-rmse:5859.87521
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5406 extra nodes, 0 pruned nodes, max_depth=30
# [74]	validation-rmse:5859.28291
# [13:03:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5440 extra nodes, 0 pruned nodes, max_depth=30
# [75]	validation-rmse:5858.74715
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5366 extra nodes, 0 pruned nodes, max_depth=30
# [76]	validation-rmse:5858.26287
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5580 extra nodes, 0 pruned nodes, max_depth=30
# [77]	validation-rmse:5857.82501
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5444 extra nodes, 0 pruned nodes, max_depth=30
# [78]	validation-rmse:5857.44707
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5544 extra nodes, 0 pruned nodes, max_depth=30
# [79]	validation-rmse:5857.08684
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5742 extra nodes, 0 pruned nodes, max_depth=30
# [80]	validation-rmse:5856.77387
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5578 extra nodes, 0 pruned nodes, max_depth=30
# [81]	validation-rmse:5856.47776
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5544 extra nodes, 0 pruned nodes, max_depth=30
# [82]	validation-rmse:5856.22283
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5452 extra nodes, 0 pruned nodes, max_depth=30
# [83]	validation-rmse:5855.98106
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5594 extra nodes, 0 pruned nodes, max_depth=30
# [84]	validation-rmse:5855.77111
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5044 extra nodes, 0 pruned nodes, max_depth=30
# [85]	validation-rmse:5855.58175
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5174 extra nodes, 0 pruned nodes, max_depth=30
# [86]	validation-rmse:5855.39785
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5324 extra nodes, 0 pruned nodes, max_depth=30
# [87]	validation-rmse:5855.22796
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5074 extra nodes, 0 pruned nodes, max_depth=30
# [88]	validation-rmse:5855.07205
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5310 extra nodes, 0 pruned nodes, max_depth=30
# [89]	validation-rmse:5854.94693
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4882 extra nodes, 0 pruned nodes, max_depth=30
# [90]	validation-rmse:5854.82152
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4816 extra nodes, 0 pruned nodes, max_depth=30
# [91]	validation-rmse:5854.70680
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4840 extra nodes, 0 pruned nodes, max_depth=30
# [92]	validation-rmse:5854.61080
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4996 extra nodes, 0 pruned nodes, max_depth=30
# [93]	validation-rmse:5854.51633
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5110 extra nodes, 0 pruned nodes, max_depth=30
# [94]	validation-rmse:5854.43114
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 5004 extra nodes, 0 pruned nodes, max_depth=30
# [95]	validation-rmse:5854.37877
# [13:03:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4836 extra nodes, 0 pruned nodes, max_depth=30
# [96]	validation-rmse:5854.30399
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4706 extra nodes, 0 pruned nodes, max_depth=30
# [97]	validation-rmse:5854.26212
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4674 extra nodes, 0 pruned nodes, max_depth=30
# [98]	validation-rmse:5854.19981
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4456 extra nodes, 0 pruned nodes, max_depth=30
# [99]	validation-rmse:5854.16565
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4778 extra nodes, 0 pruned nodes, max_depth=30
# [100]	validation-rmse:5854.11557
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4542 extra nodes, 0 pruned nodes, max_depth=30
# [101]	validation-rmse:5854.08632
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4060 extra nodes, 0 pruned nodes, max_depth=30
# [102]	validation-rmse:5854.05524
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4236 extra nodes, 0 pruned nodes, max_depth=30
# [103]	validation-rmse:5854.01230
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4426 extra nodes, 0 pruned nodes, max_depth=30
# [104]	validation-rmse:5853.97358
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4226 extra nodes, 0 pruned nodes, max_depth=30
# [105]	validation-rmse:5853.95082
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4644 extra nodes, 0 pruned nodes, max_depth=30
# [106]	validation-rmse:5853.91982
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3798 extra nodes, 0 pruned nodes, max_depth=30
# [107]	validation-rmse:5853.89031
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4042 extra nodes, 0 pruned nodes, max_depth=30
# [108]	validation-rmse:5853.87947
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4116 extra nodes, 0 pruned nodes, max_depth=30
# [109]	validation-rmse:5853.86442
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3796 extra nodes, 0 pruned nodes, max_depth=30
# [110]	validation-rmse:5853.84418
# [13:03:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3568 extra nodes, 0 pruned nodes, max_depth=30
# [111]	validation-rmse:5853.83736
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3700 extra nodes, 0 pruned nodes, max_depth=30
# [112]	validation-rmse:5853.82644
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3388 extra nodes, 0 pruned nodes, max_depth=30
# [113]	validation-rmse:5853.82005
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3872 extra nodes, 0 pruned nodes, max_depth=30
# [114]	validation-rmse:5853.80981
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3466 extra nodes, 0 pruned nodes, max_depth=30
# [115]	validation-rmse:5853.80587
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3362 extra nodes, 0 pruned nodes, max_depth=30
# [116]	validation-rmse:5853.79252
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3498 extra nodes, 0 pruned nodes, max_depth=30
# [117]	validation-rmse:5853.78993
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3306 extra nodes, 0 pruned nodes, max_depth=30
# [118]	validation-rmse:5853.78402
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2726 extra nodes, 0 pruned nodes, max_depth=30
# [119]	validation-rmse:5853.77672
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2658 extra nodes, 0 pruned nodes, max_depth=30
# [120]	validation-rmse:5853.76575
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2950 extra nodes, 0 pruned nodes, max_depth=30
# [121]	validation-rmse:5853.76396
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 3264 extra nodes, 0 pruned nodes, max_depth=30
# [122]	validation-rmse:5853.75384
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2250 extra nodes, 0 pruned nodes, max_depth=30
# [123]	validation-rmse:5853.75044
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2526 extra nodes, 0 pruned nodes, max_depth=30
# [124]	validation-rmse:5853.74539
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2396 extra nodes, 0 pruned nodes, max_depth=30
# [125]	validation-rmse:5853.73844
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2334 extra nodes, 0 pruned nodes, max_depth=30
# [126]	validation-rmse:5853.73591
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2196 extra nodes, 0 pruned nodes, max_depth=30
# [127]	validation-rmse:5853.72832
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2138 extra nodes, 0 pruned nodes, max_depth=30
# [128]	validation-rmse:5853.72583
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2424 extra nodes, 0 pruned nodes, max_depth=30
# [129]	validation-rmse:5853.72415
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2052 extra nodes, 0 pruned nodes, max_depth=30
# [130]	validation-rmse:5853.72242
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2566 extra nodes, 0 pruned nodes, max_depth=30
# [131]	validation-rmse:5853.72045
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2026 extra nodes, 0 pruned nodes, max_depth=30
# [132]	validation-rmse:5853.71559
# [13:03:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1918 extra nodes, 0 pruned nodes, max_depth=30
# [133]	validation-rmse:5853.71522
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1614 extra nodes, 0 pruned nodes, max_depth=30
# [134]	validation-rmse:5853.71129
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1898 extra nodes, 0 pruned nodes, max_depth=30
# [135]	validation-rmse:5853.71044
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1794 extra nodes, 0 pruned nodes, max_depth=30
# [136]	validation-rmse:5853.70560
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2390 extra nodes, 0 pruned nodes, max_depth=30
# [137]	validation-rmse:5853.70291
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1810 extra nodes, 0 pruned nodes, max_depth=30
# [138]	validation-rmse:5853.69853
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1604 extra nodes, 0 pruned nodes, max_depth=30
# [139]	validation-rmse:5853.70051
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1592 extra nodes, 0 pruned nodes, max_depth=30
# [140]	validation-rmse:5853.69966
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1476 extra nodes, 0 pruned nodes, max_depth=30
# [141]	validation-rmse:5853.69634
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1708 extra nodes, 0 pruned nodes, max_depth=30
# [142]	validation-rmse:5853.69629
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1586 extra nodes, 0 pruned nodes, max_depth=30
# [143]	validation-rmse:5853.69545
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 894 extra nodes, 0 pruned nodes, max_depth=30
# [144]	validation-rmse:5853.69732
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 902 extra nodes, 0 pruned nodes, max_depth=30
# [145]	validation-rmse:5853.69720
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1248 extra nodes, 0 pruned nodes, max_depth=30
# [146]	validation-rmse:5853.69720
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1066 extra nodes, 0 pruned nodes, max_depth=30
# [147]	validation-rmse:5853.69720
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 880 extra nodes, 0 pruned nodes, max_depth=30
# [148]	validation-rmse:5853.69719
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1400 extra nodes, 0 pruned nodes, max_depth=30
# [149]	validation-rmse:5853.69576
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 924 extra nodes, 0 pruned nodes, max_depth=30
# [150]	validation-rmse:5853.69575
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 780 extra nodes, 0 pruned nodes, max_depth=30
# [151]	validation-rmse:5853.69575
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1038 extra nodes, 0 pruned nodes, max_depth=30
# [152]	validation-rmse:5853.69574
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1050 extra nodes, 0 pruned nodes, max_depth=30
# [153]	validation-rmse:5853.69491
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 868 extra nodes, 0 pruned nodes, max_depth=30
# [154]	validation-rmse:5853.69178
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1450 extra nodes, 0 pruned nodes, max_depth=30
# [155]	validation-rmse:5853.69180
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1320 extra nodes, 0 pruned nodes, max_depth=30
# [156]	validation-rmse:5853.69182
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1336 extra nodes, 0 pruned nodes, max_depth=30
# [157]	validation-rmse:5853.69003
# [13:03:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1628 extra nodes, 0 pruned nodes, max_depth=30
# [158]	validation-rmse:5853.68887
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 746 extra nodes, 0 pruned nodes, max_depth=30
# [159]	validation-rmse:5853.68887
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1288 extra nodes, 0 pruned nodes, max_depth=30
# [160]	validation-rmse:5853.68680
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 502 extra nodes, 0 pruned nodes, max_depth=30
# [161]	validation-rmse:5853.68558
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 648 extra nodes, 0 pruned nodes, max_depth=30
# [162]	validation-rmse:5853.68558
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1306 extra nodes, 0 pruned nodes, max_depth=30
# [163]	validation-rmse:5853.68558
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1100 extra nodes, 0 pruned nodes, max_depth=30
# [164]	validation-rmse:5853.68558
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 726 extra nodes, 0 pruned nodes, max_depth=30
# [165]	validation-rmse:5853.68486
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 408 extra nodes, 0 pruned nodes, max_depth=30
# [166]	validation-rmse:5853.68486
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 396 extra nodes, 0 pruned nodes, max_depth=30
# [167]	validation-rmse:5853.68351
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1438 extra nodes, 0 pruned nodes, max_depth=30
# [168]	validation-rmse:5853.68351
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1494 extra nodes, 0 pruned nodes, max_depth=30
# [169]	validation-rmse:5853.68351
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1854 extra nodes, 0 pruned nodes, max_depth=30
# [170]	validation-rmse:5853.68351
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2188 extra nodes, 0 pruned nodes, max_depth=30
# [171]	validation-rmse:5853.68349
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1240 extra nodes, 0 pruned nodes, max_depth=30
# [172]	validation-rmse:5853.68349
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1576 extra nodes, 0 pruned nodes, max_depth=30
# [173]	validation-rmse:5853.68349
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2024 extra nodes, 0 pruned nodes, max_depth=30
# [174]	validation-rmse:5853.68348
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1990 extra nodes, 0 pruned nodes, max_depth=30
# [175]	validation-rmse:5853.68347
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1276 extra nodes, 0 pruned nodes, max_depth=30
# [176]	validation-rmse:5853.68330
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2094 extra nodes, 0 pruned nodes, max_depth=30
# [177]	validation-rmse:5853.68330
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1002 extra nodes, 0 pruned nodes, max_depth=30
# [178]	validation-rmse:5853.68330
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1282 extra nodes, 0 pruned nodes, max_depth=30
# [179]	validation-rmse:5853.68330
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1178 extra nodes, 0 pruned nodes, max_depth=30
# [180]	validation-rmse:5853.68330
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 534 extra nodes, 0 pruned nodes, max_depth=30
# [181]	validation-rmse:5853.68330
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1406 extra nodes, 0 pruned nodes, max_depth=30
# [182]	validation-rmse:5853.68291
# [13:03:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 560 extra nodes, 0 pruned nodes, max_depth=30
# [183]	validation-rmse:5853.68291
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1656 extra nodes, 0 pruned nodes, max_depth=30
# [184]	validation-rmse:5853.68291
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 732 extra nodes, 0 pruned nodes, max_depth=30
# [185]	validation-rmse:5853.68290
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1572 extra nodes, 0 pruned nodes, max_depth=30
# [186]	validation-rmse:5853.68290
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1508 extra nodes, 0 pruned nodes, max_depth=30
# [187]	validation-rmse:5853.68136
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1130 extra nodes, 0 pruned nodes, max_depth=30
# [188]	validation-rmse:5853.67991
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1664 extra nodes, 0 pruned nodes, max_depth=30
# [189]	validation-rmse:5853.67991
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1396 extra nodes, 0 pruned nodes, max_depth=30
# [190]	validation-rmse:5853.67991
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1078 extra nodes, 0 pruned nodes, max_depth=30
# [191]	validation-rmse:5853.67991
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1078 extra nodes, 0 pruned nodes, max_depth=30
# [192]	validation-rmse:5853.67991
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1384 extra nodes, 0 pruned nodes, max_depth=30
# [193]	validation-rmse:5853.67952
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2510 extra nodes, 0 pruned nodes, max_depth=30
# [194]	validation-rmse:5853.67998
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2126 extra nodes, 0 pruned nodes, max_depth=30
# [195]	validation-rmse:5853.67885
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1174 extra nodes, 0 pruned nodes, max_depth=30
# [196]	validation-rmse:5853.67885
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2166 extra nodes, 0 pruned nodes, max_depth=30
# [197]	validation-rmse:5853.67959
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1210 extra nodes, 0 pruned nodes, max_depth=30
# [198]	validation-rmse:5853.67959
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2106 extra nodes, 0 pruned nodes, max_depth=30
# [199]	validation-rmse:5853.67888
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1396 extra nodes, 0 pruned nodes, max_depth=30
# [200]	validation-rmse:5853.67812
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1980 extra nodes, 0 pruned nodes, max_depth=30
# [201]	validation-rmse:5853.67804
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 722 extra nodes, 0 pruned nodes, max_depth=30
# [202]	validation-rmse:5853.67731
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1282 extra nodes, 0 pruned nodes, max_depth=30
# [203]	validation-rmse:5853.67653
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1216 extra nodes, 0 pruned nodes, max_depth=30
# [204]	validation-rmse:5853.67575
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1234 extra nodes, 0 pruned nodes, max_depth=30
# [205]	validation-rmse:5853.67529
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1132 extra nodes, 0 pruned nodes, max_depth=30
# [206]	validation-rmse:5853.67529
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1262 extra nodes, 0 pruned nodes, max_depth=30
# [207]	validation-rmse:5853.67529
# [13:03:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1224 extra nodes, 0 pruned nodes, max_depth=30
# [208]	validation-rmse:5853.67529
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1388 extra nodes, 0 pruned nodes, max_depth=30
# [209]	validation-rmse:5853.67527
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1000 extra nodes, 0 pruned nodes, max_depth=30
# [210]	validation-rmse:5853.67527
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 526 extra nodes, 0 pruned nodes, max_depth=30
# [211]	validation-rmse:5853.67527
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 996 extra nodes, 0 pruned nodes, max_depth=30
# [212]	validation-rmse:5853.67527
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 646 extra nodes, 0 pruned nodes, max_depth=30
# [213]	validation-rmse:5853.67527
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1134 extra nodes, 0 pruned nodes, max_depth=30
# [214]	validation-rmse:5853.67488
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1258 extra nodes, 0 pruned nodes, max_depth=30
# [215]	validation-rmse:5853.67488
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 508 extra nodes, 0 pruned nodes, max_depth=30
# [216]	validation-rmse:5853.67488
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1220 extra nodes, 0 pruned nodes, max_depth=30
# [217]	validation-rmse:5853.67451
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1440 extra nodes, 0 pruned nodes, max_depth=30
# [218]	validation-rmse:5853.67373
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1208 extra nodes, 0 pruned nodes, max_depth=30
# [219]	validation-rmse:5853.67299
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 834 extra nodes, 0 pruned nodes, max_depth=30
# [220]	validation-rmse:5853.67299
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1404 extra nodes, 0 pruned nodes, max_depth=30
# [221]	validation-rmse:5853.67300
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1610 extra nodes, 0 pruned nodes, max_depth=30
# [222]	validation-rmse:5853.67229
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1548 extra nodes, 0 pruned nodes, max_depth=30
# [223]	validation-rmse:5853.67230
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 882 extra nodes, 0 pruned nodes, max_depth=30
# [224]	validation-rmse:5853.67230
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1728 extra nodes, 0 pruned nodes, max_depth=30
# [225]	validation-rmse:5853.67231
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1254 extra nodes, 0 pruned nodes, max_depth=30
# [226]	validation-rmse:5853.67152
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 768 extra nodes, 0 pruned nodes, max_depth=30
# [227]	validation-rmse:5853.67112
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1192 extra nodes, 0 pruned nodes, max_depth=30
# [228]	validation-rmse:5853.67112
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 998 extra nodes, 0 pruned nodes, max_depth=30
# [229]	validation-rmse:5853.67112
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1054 extra nodes, 0 pruned nodes, max_depth=30
# [230]	validation-rmse:5853.67111
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1096 extra nodes, 0 pruned nodes, max_depth=30
# [231]	validation-rmse:5853.67071
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 536 extra nodes, 0 pruned nodes, max_depth=30
# [232]	validation-rmse:5853.67071
# [13:03:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2040 extra nodes, 0 pruned nodes, max_depth=30
# [233]	validation-rmse:5853.67031
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2272 extra nodes, 0 pruned nodes, max_depth=30
# [234]	validation-rmse:5853.67032
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2216 extra nodes, 0 pruned nodes, max_depth=30
# [235]	validation-rmse:5853.67023
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1986 extra nodes, 0 pruned nodes, max_depth=30
# [236]	validation-rmse:5853.67018
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1618 extra nodes, 0 pruned nodes, max_depth=30
# [237]	validation-rmse:5853.66944
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1344 extra nodes, 0 pruned nodes, max_depth=30
# [238]	validation-rmse:5853.66940
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1364 extra nodes, 0 pruned nodes, max_depth=30
# [239]	validation-rmse:5853.66943
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1686 extra nodes, 0 pruned nodes, max_depth=30
# [240]	validation-rmse:5853.66942
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1536 extra nodes, 0 pruned nodes, max_depth=30
# [241]	validation-rmse:5853.66864
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1246 extra nodes, 0 pruned nodes, max_depth=30
# [242]	validation-rmse:5853.66867
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1244 extra nodes, 0 pruned nodes, max_depth=30
# [243]	validation-rmse:5853.66867
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1732 extra nodes, 0 pruned nodes, max_depth=30
# [244]	validation-rmse:5853.66869
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1478 extra nodes, 0 pruned nodes, max_depth=30
# [245]	validation-rmse:5853.66874
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1602 extra nodes, 0 pruned nodes, max_depth=30
# [246]	validation-rmse:5853.66874
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1774 extra nodes, 0 pruned nodes, max_depth=30
# [247]	validation-rmse:5853.66875
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1746 extra nodes, 0 pruned nodes, max_depth=30
# [248]	validation-rmse:5853.66868
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1260 extra nodes, 0 pruned nodes, max_depth=30
# [249]	validation-rmse:5853.66865
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1250 extra nodes, 0 pruned nodes, max_depth=30
# [250]	validation-rmse:5853.66865
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1976 extra nodes, 0 pruned nodes, max_depth=30
# [251]	validation-rmse:5853.66868
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1880 extra nodes, 0 pruned nodes, max_depth=30
# [252]	validation-rmse:5853.66869
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 968 extra nodes, 0 pruned nodes, max_depth=30
# [253]	validation-rmse:5853.66869
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1104 extra nodes, 0 pruned nodes, max_depth=30
# [254]	validation-rmse:5853.66869
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1356 extra nodes, 0 pruned nodes, max_depth=30
# [255]	validation-rmse:5853.66869
# [13:03:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1008 extra nodes, 0 pruned nodes, max_depth=30
# [256]	validation-rmse:5853.66869
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 828 extra nodes, 0 pruned nodes, max_depth=30
# [257]	validation-rmse:5853.66869
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 870 extra nodes, 0 pruned nodes, max_depth=30
# [258]	validation-rmse:5853.66869
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1096 extra nodes, 0 pruned nodes, max_depth=30
# [259]	validation-rmse:5853.66869
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1132 extra nodes, 0 pruned nodes, max_depth=30
# [260]	validation-rmse:5853.66869
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1514 extra nodes, 0 pruned nodes, max_depth=30
# [261]	validation-rmse:5853.66866
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1266 extra nodes, 0 pruned nodes, max_depth=30
# [262]	validation-rmse:5853.66866
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1280 extra nodes, 0 pruned nodes, max_depth=30
# [263]	validation-rmse:5853.66866
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 998 extra nodes, 0 pruned nodes, max_depth=30
# [264]	validation-rmse:5853.66866
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1768 extra nodes, 0 pruned nodes, max_depth=30
# [265]	validation-rmse:5853.66866
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2282 extra nodes, 0 pruned nodes, max_depth=30
# [266]	validation-rmse:5853.66864
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1784 extra nodes, 0 pruned nodes, max_depth=30
# [267]	validation-rmse:5853.66864
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1734 extra nodes, 0 pruned nodes, max_depth=30
# [268]	validation-rmse:5853.66864
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1948 extra nodes, 0 pruned nodes, max_depth=30
# [269]	validation-rmse:5853.66867
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2174 extra nodes, 0 pruned nodes, max_depth=30
# [270]	validation-rmse:5853.66867
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2134 extra nodes, 0 pruned nodes, max_depth=30
# [271]	validation-rmse:5853.66867
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1308 extra nodes, 0 pruned nodes, max_depth=30
# [272]	validation-rmse:5853.66868
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1824 extra nodes, 0 pruned nodes, max_depth=30
# [273]	validation-rmse:5853.66868
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1926 extra nodes, 0 pruned nodes, max_depth=30
# [274]	validation-rmse:5853.66868
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2322 extra nodes, 0 pruned nodes, max_depth=30
# [275]	validation-rmse:5853.66868
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2148 extra nodes, 0 pruned nodes, max_depth=30
# [276]	validation-rmse:5853.66868
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1142 extra nodes, 0 pruned nodes, max_depth=30
# [277]	validation-rmse:5853.66796
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1886 extra nodes, 0 pruned nodes, max_depth=30
# [278]	validation-rmse:5853.66796
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2044 extra nodes, 0 pruned nodes, max_depth=30
# [279]	validation-rmse:5853.66796
# [13:03:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1726 extra nodes, 0 pruned nodes, max_depth=30
# [280]	validation-rmse:5853.66796
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2310 extra nodes, 0 pruned nodes, max_depth=30
# [281]	validation-rmse:5853.66796
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1296 extra nodes, 0 pruned nodes, max_depth=30
# [282]	validation-rmse:5853.66796
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1496 extra nodes, 0 pruned nodes, max_depth=30
# [283]	validation-rmse:5853.66796
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1878 extra nodes, 0 pruned nodes, max_depth=30
# [284]	validation-rmse:5853.66796
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1658 extra nodes, 0 pruned nodes, max_depth=30
# [285]	validation-rmse:5853.66797
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1522 extra nodes, 0 pruned nodes, max_depth=30
# [286]	validation-rmse:5853.66797
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1748 extra nodes, 0 pruned nodes, max_depth=30
# [287]	validation-rmse:5853.66797
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1880 extra nodes, 0 pruned nodes, max_depth=30
# [288]	validation-rmse:5853.66797
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1068 extra nodes, 0 pruned nodes, max_depth=30
# [289]	validation-rmse:5853.66797
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1382 extra nodes, 0 pruned nodes, max_depth=30
# [290]	validation-rmse:5853.66794
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 598 extra nodes, 0 pruned nodes, max_depth=30
# [291]	validation-rmse:5853.66794
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 984 extra nodes, 0 pruned nodes, max_depth=30
# [292]	validation-rmse:5853.66794
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1370 extra nodes, 0 pruned nodes, max_depth=30
# [293]	validation-rmse:5853.66794
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1096 extra nodes, 0 pruned nodes, max_depth=30
# [294]	validation-rmse:5853.66794
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 776 extra nodes, 0 pruned nodes, max_depth=30
# [295]	validation-rmse:5853.66794
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=30
# [296]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1260 extra nodes, 0 pruned nodes, max_depth=30
# [297]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2752 extra nodes, 0 pruned nodes, max_depth=30
# [298]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1776 extra nodes, 0 pruned nodes, max_depth=30
# [299]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1754 extra nodes, 0 pruned nodes, max_depth=30
# [300]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1186 extra nodes, 0 pruned nodes, max_depth=30
# [301]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1590 extra nodes, 0 pruned nodes, max_depth=30
# [302]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2368 extra nodes, 0 pruned nodes, max_depth=30
# [303]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1222 extra nodes, 0 pruned nodes, max_depth=30
# [304]	validation-rmse:5853.66795
# [13:03:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 686 extra nodes, 0 pruned nodes, max_depth=30
# [305]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 994 extra nodes, 0 pruned nodes, max_depth=30
# [306]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 930 extra nodes, 0 pruned nodes, max_depth=30
# [307]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1510 extra nodes, 0 pruned nodes, max_depth=30
# [308]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1368 extra nodes, 0 pruned nodes, max_depth=30
# [309]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1990 extra nodes, 0 pruned nodes, max_depth=30
# [310]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1626 extra nodes, 0 pruned nodes, max_depth=30
# [311]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2020 extra nodes, 0 pruned nodes, max_depth=30
# [312]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1594 extra nodes, 0 pruned nodes, max_depth=30
# [313]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1976 extra nodes, 0 pruned nodes, max_depth=30
# [314]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1680 extra nodes, 0 pruned nodes, max_depth=30
# [315]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2416 extra nodes, 0 pruned nodes, max_depth=30
# [316]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1898 extra nodes, 0 pruned nodes, max_depth=30
# [317]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1842 extra nodes, 0 pruned nodes, max_depth=30
# [318]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2272 extra nodes, 0 pruned nodes, max_depth=30
# [319]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1494 extra nodes, 0 pruned nodes, max_depth=30
# [320]	validation-rmse:5853.66795
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1688 extra nodes, 0 pruned nodes, max_depth=30
# [321]	validation-rmse:5853.66793
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2274 extra nodes, 0 pruned nodes, max_depth=30
# [322]	validation-rmse:5853.66793
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1686 extra nodes, 0 pruned nodes, max_depth=30
# [323]	validation-rmse:5853.66791
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2226 extra nodes, 0 pruned nodes, max_depth=30
# [324]	validation-rmse:5853.66791
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2456 extra nodes, 0 pruned nodes, max_depth=30
# [325]	validation-rmse:5853.66791
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2346 extra nodes, 0 pruned nodes, max_depth=30
# [326]	validation-rmse:5853.66791
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 2790 extra nodes, 0 pruned nodes, max_depth=30
# [327]	validation-rmse:5853.66791
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1884 extra nodes, 0 pruned nodes, max_depth=30
# [328]	validation-rmse:5853.66791
# [13:03:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1576 extra nodes, 0 pruned nodes, max_depth=30
# [329]	validation-rmse:5853.66791
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1954 extra nodes, 0 pruned nodes, max_depth=30
# [330]	validation-rmse:5853.66791
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1992 extra nodes, 0 pruned nodes, max_depth=30
# [331]	validation-rmse:5853.66791
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1546 extra nodes, 0 pruned nodes, max_depth=30
# [332]	validation-rmse:5853.66791
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1176 extra nodes, 0 pruned nodes, max_depth=30
# [333]	validation-rmse:5853.66791
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1672 extra nodes, 0 pruned nodes, max_depth=30
# [334]	validation-rmse:5853.66791
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1334 extra nodes, 0 pruned nodes, max_depth=30
# [335]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1694 extra nodes, 0 pruned nodes, max_depth=30
# [336]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1522 extra nodes, 0 pruned nodes, max_depth=30
# [337]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1636 extra nodes, 0 pruned nodes, max_depth=30
# [338]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1402 extra nodes, 0 pruned nodes, max_depth=30
# [339]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 822 extra nodes, 0 pruned nodes, max_depth=30
# [340]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 786 extra nodes, 0 pruned nodes, max_depth=30
# [341]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1386 extra nodes, 0 pruned nodes, max_depth=30
# [342]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 848 extra nodes, 0 pruned nodes, max_depth=30
# [343]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1360 extra nodes, 0 pruned nodes, max_depth=30
# [344]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=30
# [345]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1052 extra nodes, 0 pruned nodes, max_depth=30
# [346]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1326 extra nodes, 0 pruned nodes, max_depth=30
# [347]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1474 extra nodes, 0 pruned nodes, max_depth=30
# [348]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1396 extra nodes, 0 pruned nodes, max_depth=30
# [349]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1756 extra nodes, 0 pruned nodes, max_depth=30
# [350]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 928 extra nodes, 0 pruned nodes, max_depth=30
# [351]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 744 extra nodes, 0 pruned nodes, max_depth=30
# [352]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 822 extra nodes, 0 pruned nodes, max_depth=30
# [353]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 868 extra nodes, 0 pruned nodes, max_depth=30
# [354]	validation-rmse:5853.66790
# [13:03:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1226 extra nodes, 0 pruned nodes, max_depth=30
# [355]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1276 extra nodes, 0 pruned nodes, max_depth=30
# [356]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1426 extra nodes, 0 pruned nodes, max_depth=30
# [357]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1068 extra nodes, 0 pruned nodes, max_depth=30
# [358]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1014 extra nodes, 0 pruned nodes, max_depth=30
# [359]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1182 extra nodes, 0 pruned nodes, max_depth=30
# [360]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1568 extra nodes, 0 pruned nodes, max_depth=30
# [361]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1162 extra nodes, 0 pruned nodes, max_depth=30
# [362]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1532 extra nodes, 0 pruned nodes, max_depth=30
# [363]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1316 extra nodes, 0 pruned nodes, max_depth=30
# [364]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1144 extra nodes, 0 pruned nodes, max_depth=30
# [365]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1284 extra nodes, 0 pruned nodes, max_depth=30
# [366]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1532 extra nodes, 0 pruned nodes, max_depth=30
# [367]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1402 extra nodes, 0 pruned nodes, max_depth=30
# [368]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 876 extra nodes, 0 pruned nodes, max_depth=30
# [369]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 836 extra nodes, 0 pruned nodes, max_depth=30
# [370]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 818 extra nodes, 0 pruned nodes, max_depth=30
# [371]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1032 extra nodes, 0 pruned nodes, max_depth=30
# [372]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 958 extra nodes, 0 pruned nodes, max_depth=30
# [373]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1060 extra nodes, 0 pruned nodes, max_depth=30
# [374]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1066 extra nodes, 0 pruned nodes, max_depth=30
# [375]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 830 extra nodes, 0 pruned nodes, max_depth=30
# [376]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 840 extra nodes, 0 pruned nodes, max_depth=30
# [377]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 794 extra nodes, 0 pruned nodes, max_depth=30
# [378]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 906 extra nodes, 0 pruned nodes, max_depth=30
# [379]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 798 extra nodes, 0 pruned nodes, max_depth=30
# [380]	validation-rmse:5853.66790
# [13:03:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1116 extra nodes, 0 pruned nodes, max_depth=30
# [381]	validation-rmse:5853.66790
# [13:03:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 1048 extra nodes, 0 pruned nodes, max_depth=30
# [382]	validation-rmse:5853.66790
# [13:03:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 996 extra nodes, 0 pruned nodes, max_depth=30
# [383]	validation-rmse:5853.66790
# [13:03:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 900 extra nodes, 0 pruned nodes, max_depth=30
# [384]	validation-rmse:5853.66790
# [13:03:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 910 extra nodes, 0 pruned nodes, max_depth=30
# [13:04:00] ======== Monitor (0): Learner ========
# [13:04:00] Configure: 0.001s, 1 calls @ 1000us
#
# [13:04:00] EvalOneIter: 0.628478s, 386 calls @ 628478us
#
# [13:04:00] GetGradient: 0.008305s, 386 calls @ 8305us
#
# [13:04:00] PredictRaw: 0.731724s, 386 calls @ 731724us
#
# [13:04:00] UpdateOneIter: 13.0332s, 386 calls @ 13033194us
#
# [13:04:00] ======== Monitor (0): GBTree ========
# [13:04:00] BoostNewTrees: 12.2849s, 386 calls @ 12284850us
#
# [13:04:00] CommitModel: 0.000576s, 386 calls @ 576us
#
# [13:04:00] ======== Monitor (0): TreePruner ========
# [13:04:00] PrunerUpdate: 0.201548s, 386 calls @ 201548us
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[67], line 48
#      45 mlflow.log_metric("error_percentage", error_percentage)
#      47 # Save model locally
# ---> 48 mlflow.xgboost.save_model(booster, "/tmp/models_mlflow")
#      50 # Save the preprocessor locally
#      51 with open("/tmp/preprocessor.pkl", "wb") as f_out:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/mlflow/xgboost/__init__.py:154, in save_model(xgb_model, path, conda_env, code_paths, mlflow_model, signature, input_example, pip_requirements, extra_pip_requirements, model_format, metadata)
#     151 _validate_env_arguments(conda_env, pip_requirements, extra_pip_requirements)
#     153 path = os.path.abspath(path)
# --> 154 _validate_and_prepare_target_save_path(path)
#     155 code_dir_subpath = _validate_and_copy_code_paths(code_paths, path)
#     157 if mlflow_model is None:
#
# File ~/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/mlflow/utils/model_utils.py:129, in _validate_and_prepare_target_save_path(path)
#     127 def _validate_and_prepare_target_save_path(path):
#     128     if os.path.exists(path) and any(os.scandir(path)):
# --> 129         raise MlflowException(
#     130             message=f"Path '{path}' already exists and is not empty",
#     131             error_code=RESOURCE_ALREADY_EXISTS,
#     132         )
#     134     os.makedirs(path, exist_ok=True)
#
# MlflowException: Path '/tmp/models_mlflow' already exists and is not empty

# %% [markdown]
# # Model Registry

# %%
from mlflow.tracking import MlflowClient

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"

# %% [markdown]
# ## Interacting with the MLflow tracking server¶
# The MlflowClient object allows us to interact with...
#
# an MLflow Tracking Server that creates and manages experiments and runs.
# an MLflow Registry Server that creates and manages registered models and model versions.
# To instantiate it we need to pass a tracking URI and/or a registry URI

# %%
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

client.list_experiments()

# %%
for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']:.4f}")

# %% [markdown]
# ### Interacting with the Model Registry
#
# In this section We will use the `MlflowClient` instance to:
#
# 1. Register a new version for the experiment `nyc-taxi-regressor`
# 2. Retrieve the latests versions of the model `nyc-taxi-regressor` and check that a new version `4` was created.
# 3. Transition the version `4` to "Staging" and adding annotations to it.

# %%
run_id = "b8904012c84343b5bf8ee72aa8f0f402"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri=model_uri, name="nyc-taxi-regressor")

# %%
model_name = "nyc-taxi-regressor"
latest_versions = client.get_latest_versions(name=model_name)

for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")

# %%
model_version = 4
new_stage = "Staging"
client.transition_model_version_stage(
    name=model_name,
    version=model_version,
    stage=new_stage,
    archive_existing_versions=False
)

# %%
from datetime import datetime

date = datetime.today().date()
client.update_model_version(
    name=model_name,
    version=model_version,
    description=f"The model version {model_version} was transitioned to {new_stage} on {date}"
)

# %%
# %time test_model(name=model_name, stage="Production", X_test=X_test, y_test=y_test)

# %%
client.transition_model_version_stage(
    name=model_name,
    version=4,
    stage="Production",
    archive_existing_versions=True
)
